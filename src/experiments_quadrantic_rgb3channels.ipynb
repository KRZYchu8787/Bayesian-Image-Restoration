# %% [markdown]
# # Quadrantic RGB 3 Channels Experiment

# %%
from restorationRGB3channels import process_image_quadratic_rgb3channels
import matplotlib.pyplot as plt
import numpy as np
import random
seed = 42
np.random.seed(seed)
random.seed(seed)

# %%
file='iphone.png'
_,_,_,_,_ = process_image_quadratic_rgb3channels(file)

# %%
file = 'cam.png'
_,_,_,_,_ = process_image_quadratic_rgb3channels(file, sigma=14)
